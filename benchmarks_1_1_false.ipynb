# %% [markdown]
# # DATAIMPORT/ CLEANUP

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob

import scipy.stats as stats

# %%
#orders_reeat_aot
suffix = "1_1_false"
existFilePath = os.path.join(r"D:\projects\private\Bachelorarbeit_Blazor_Wasm\BenchmarkResults", f"dfAll_{suffix}.csv")

if os.path.exists(existFilePath):
    dfAll = pd.read_csv(existFilePath)
else:
   
    path = r"C:\Users\cr\Downloads"
    dfAll = pd.DataFrame()

    for version in range(6):
        pattern = os.path.join(path, f"Version{version}_*{suffix}.txt")
        files = glob.glob(pattern)

        if files:
            for file in files:
                df = pd.read_csv(file, header=0, names=["ObjInstance", "Identifier", "MethodName", "ElapsedMilliseconds"])
                df["Version"] = f"Version{version}"
                df = df.loc[df.groupby(["ObjInstance", "MethodName"])["ElapsedMilliseconds"].idxmax()]
                dfAll = pd.concat([dfAll, df], ignore_index=True)

    dfAll.to_csv(existFilePath, index=False, encoding="utf-8")

# %%
dfAll = dfAll.dropna(subset=["ElapsedMilliseconds"])
dfAll = dfAll.drop_duplicates(subset=["ObjInstance", "Identifier", "MethodName", "ElapsedMilliseconds"])

dfAll["ElapsedMilliseconds"] = pd.to_numeric(dfAll["ElapsedMilliseconds"])
dfAll = dfAll[dfAll["ElapsedMilliseconds"] >= 0]

#Reihenfolge für Plots
custom_order = [
    "SetParam",
    "SetParam_OnInit",
    "GenerateOrders",
    "PopulateChartOrderState",
    "OnInit_OnParam",
    "OnParam_OnAfterRender",
    "VisualizeOrderStatusSuccess",
    "FINISH"
]

lifecycle = [
    "SetParam",
    "SetParam_OnInit",
    "OnInit_OnParam",
    "OnParam_OnAfterRender",
    "FINISH"
]


dfAll["MethodName"] = pd.Categorical(dfAll["MethodName"], categories=custom_order, ordered=True)
#Um das Gruppieren zum umgehen und bei Plots nach Version und Komponente zu unterscheiden
dfAll.loc[:, "VersionObjInstance"] = dfAll["Version"].astype(str) + " - " + dfAll["ObjInstance"].astype(str)

dfLifecycle = dfAll[dfAll["MethodName"].isin(lifecycle)]
dfLifecycle.loc[:, "VersionObjInstance"] = dfAll["Version"].astype(str) + " - " + dfAll["ObjInstance"].astype(str)

# %%
dfAll.head()
# Out:
#           ObjInstance                            Identifier  \
# 0  BenchmarkComponent  0675bb23-45e0-4697-acf4-63ab35515735
# 1  BenchmarkComponent  0675bb23-45e0-4697-acf4-63ab35515735
# 2  BenchmarkComponent  0675bb23-45e0-4697-acf4-63ab35515735
# 3  BenchmarkComponent  0675bb23-45e0-4697-acf4-63ab35515735
# 4  BenchmarkComponent  0675bb23-45e0-4697-acf4-63ab35515735
#
#               MethodName  ElapsedMilliseconds   Version  \
# 0                 FINISH                  507  Version0
# 1         OnInit_OnParam                  437  Version0
# 2  OnParam_OnAfterRender                  507  Version0
# 3               SetParam                  433  Version0
# 4        SetParam_OnInit                  436  Version0
#
#               VersionObjInstance
# 0  Version0 - BenchmarkComponent
# 1  Version0 - BenchmarkComponent
# 2  Version0 - BenchmarkComponent
# 3  Version0 - BenchmarkComponent
# 4  Version0 - BenchmarkComponent

# %% [markdown]
# # CHECK SIGNIFICANCE

# %% [markdown]
# ## PLOT

# %%
fig, ax = plt.subplots(figsize=(12, 6))

sns.boxplot(data=dfAll, x="MethodName", y="ElapsedMilliseconds", hue="VersionObjInstance", ax=ax)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_xlabel("Methodenname")
ax.set_ylabel("ElapsedMilliseconds")

plt.legend(title="Version+Komponenten", bbox_to_anchor=(1.05, 0.5), loc="center left")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\3883553201.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 8))

sns.boxplot(data=dfAll, x="MethodName", y="ElapsedMilliseconds", hue="VersionObjInstance", ax=ax1, legend=False)
ax1.set_ylim(5, 30)

sns.boxplot(data=dfAll, x="MethodName", y="ElapsedMilliseconds", hue="VersionObjInstance", ax=ax2 , legend=False)
ax2.set_ylim(325, 550)

sns.boxplot(data=dfAll, x="MethodName", y="ElapsedMilliseconds", hue="VersionObjInstance", ax=ax3)
ax3.set_ylim(850, 1000)

for ax in [ax1, ax2, ax3]:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    ax.set_xlabel("Methodenname")
    ax.set_ylabel("ElapsedMilliseconds")

plt.legend(title="Version+Komponenten", bbox_to_anchor=(1.05, 0.5), loc="center left")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\2208836945.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\2208836945.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\2208836945.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
#chatgpt
def remove_outliers_grouped(df, value_col, group_cols, threshold=1.49):
    def filter_group(group):
        Q1 = group[value_col].quantile(0.25)
        Q3 = group[value_col].quantile(0.75)
        IQR = Q3 - Q1

        if IQR == 0:
            IQR = 1
        
        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR
        
        return group[(group[value_col] > lower_bound) & (group[value_col] < upper_bound)]
    
    return df.groupby(group_cols, group_keys=False).apply(filter_group)

dfAll = remove_outliers_grouped(dfAll, "ElapsedMilliseconds", ["MethodName", "VersionObjInstance"])
# Out:
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\1209126819.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   return df.groupby(group_cols, group_keys=False).apply(filter_group)
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\1209126819.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(group_cols, group_keys=False).apply(filter_group)

# %%
uniqueVersionObjInstances = dfAll["VersionObjInstance"].unique()

plots = len(uniqueVersionObjInstances)
cols = 3  
rows = (plots + cols - 1) // cols 

fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows), sharey=True)
axes = axes.flatten()  

for i, VersionObjInstance in enumerate(uniqueVersionObjInstances):
    ax = axes[i]
    
    sns.kdeplot(data=dfAll[dfAll["VersionObjInstance"] == VersionObjInstance], 
                x="ElapsedMilliseconds", 
                hue="MethodName", 
                fill=True, 
                common_norm=False, 
                legend=True if i % 3 == 0 else False,
                ax=ax)
    ax.set_title(f"{VersionObjInstance}")
    ax.set_xlabel("ElapsedMilliseconds")
    ax.set_ylabel("Dichte")
    ax.set_ylim(0, 0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## CALCULATION

# %%
uniqueVersionObjInstances = dfAll["VersionObjInstance"].unique()
uniqueMethods = dfAll["MethodName"].unique()

for version in uniqueVersionObjInstances:
    versionObjIni = dfAll[dfAll["VersionObjInstance"] == version]
    print(f"\n{version}")
    for method in uniqueMethods:
        #Fehler, weil kindkomponente nur lifecyclemethoden hat
        if (method not in lifecycle and (versionObjIni["ObjInstance"] == "BenchmarkComponent").any()):
            continue

        data = versionObjIni[versionObjIni["MethodName"] == method]["ElapsedMilliseconds"]
        if len(data) > 2:  
            modeResult = stats.mode(data).mode
            median = data.median()
            mean = data.mean()
            skew = stats.skew(data)
            
            # Unbiased Standardabweichung
            std = np.std(data, ddof=1) 
             # Variationskoeffizient
            vc = (std / mean) * 100 
             
            if vc > 5:
                print(f"Methode: {method}; Modus: {modeResult}; Median: {median}; Std: {vc:.2f}")
            
            if skew > 1:
                print(f"Methode: {method}; Rechtsschiefe: {skew:.2f};")
            if skew < -1:
                print(f"Methode: {method}; Linksschiefe: {skew:.2f};")
        else:
            print(f"Methode: {method}; Zu wenige Datenpunkte für Berechnungen.")
# Out:
# Version0 - BenchmarkComponent
# Methode: SetParam; Rechtsschiefe: 1.14;
# Methode: SetParam_OnInit; Rechtsschiefe: 1.16;
# Methode: OnInit_OnParam; Rechtsschiefe: 1.11;
# Methode: OnParam_OnAfterRender; Rechtsschiefe: 1.08;
# Methode: FINISH; Rechtsschiefe: 1.06;
#
# Version0 - VersionComponent
# Methode: SetParam; Modus: 9; Median: 9.0; Std: 5.77
# Methode: PopulateChartOrderState; Modus: 11; Median: 11.0; Std: 5.48
# Methode: PopulateChartOrderState; Rechtsschiefe: 1.56;
# Methode: VisualizeOrderStatusSuccess; Rechtsschiefe: 1.16;
# Methode: FINISH; Rechtsschiefe: 1.07;
#
# Version1 - BenchmarkComponent
#
# Version1 - VersionComponent
# Methode: SetParam; Modus: 8; Median: 8.0; Std: 6.55
# Methode: PopulateChartOrderState; Rechtsschiefe: 2.04;
# Methode: VisualizeOrderStatusSuccess; Rechtsschiefe: 1.04;
#
# Version2 - BenchmarkComponent
#
# Version2 - VersionComponent
# Methode: SetParam; Modus: 8; Median: 8.0; Std: 5.94
# Methode: PopulateChartOrderState; Rechtsschiefe: 1.46;
#
# Version3 - BenchmarkComponent
#
# Version3 - VersionComponent
# Methode: SetParam; Modus: 9; Median: 9.0; Std: 6.31
# Methode: PopulateChartOrderState; Rechtsschiefe: 1.99;
#
# Version4 - VersionComponent
# Methode: SetParam; Modus: 9; Median: 9.0; Std: 5.99
#
# Version5 - VersionComponent
# Methode: SetParam; Modus: 9; Median: 9.0; Std: 6.73
# Methode: GenerateOrders; Rechtsschiefe: 1.03;
# Methode: PopulateChartOrderState; Rechtsschiefe: 1.45;
# Methode: OnInit_OnParam; Rechtsschiefe: 1.08;
# Methode: OnParam_OnAfterRender; Rechtsschiefe: 1.02;
# Methode: FINISH; Rechtsschiefe: 1.02;

# %%
def printStats(stats):
    print(f"{method}")
    print(stats,"\n") 


for VersionObjInstance in uniqueVersionObjInstances:

    versionA = dfAll.loc[dfAll["VersionObjInstance"] == VersionObjInstance]
    versionANum = versionA["Version"].str[-1].astype(int).iloc[0]
    versionB = dfAll.loc[
    (dfAll["Version"] == f"Version{versionANum + 1}") & 
    (dfAll["ObjInstance"] == versionA["ObjInstance"].iloc[0])
    ]
    if versionB.empty:
        continue
    print(f"\n{versionB["VersionObjInstance"].iloc[0]} zu {versionA["Version"].iloc[0]}")

    for method in uniqueMethods:
        if (method not in lifecycle and (versionA["ObjInstance"] == "BenchmarkComponent").any() or
            method not in lifecycle and (versionB["ObjInstance"] == "BenchmarkComponent").any()):
            continue
        
        statsTxt = ""
        versionAval = versionA[versionA["MethodName"] == method]["ElapsedMilliseconds"]
        versionBval = versionB[versionB["MethodName"] == method]["ElapsedMilliseconds"]
        
        if len(versionAval) < 2 or len(versionBval) < 2:
            print(f"Zu wenig Daten für {method}.")
            continue

        tStat, pVal = stats.ttest_ind(versionAval, versionBval, equal_var=False)
        uStatmann, pValmann = stats.mannwhitneyu(versionAval, versionBval)
        
        if pVal > 0.05:
            statsTxt += f"  welchs-statistik = {tStat}, p-Wert = {pVal}\n"
        
        if pValmann > 0.05:
            statsTxt += f"  Mann-U-statistik = {uStatmann}, p-Wert = {pValmann}"
        
        if statsTxt:
            printStats(statsTxt)
# Out:
# Version1 - BenchmarkComponent zu Version0
# SetParam
#   welchs-statistik = 1.8191443661766993, p-Wert = 0.0749577908653449
#   Mann-U-statistik = 667.0, p-Wert = 0.7943135062584431
#
# SetParam_OnInit
#   welchs-statistik = 1.979766969479306, p-Wert = 0.05337709783664728
#   Mann-U-statistik = 684.5, p-Wert = 0.6462203450704959
#
# OnInit_OnParam
#   welchs-statistik = 1.988069832729922, p-Wert = 0.05235634480974455
#   Mann-U-statistik = 691.0, p-Wert = 0.5941713320100144
#
# OnParam_OnAfterRender
#   welchs-statistik = 1.054281443269166, p-Wert = 0.2959003609983792
#   Mann-U-statistik = 648.5, p-Wert = 0.8766217755682162
#
# FINISH
#   welchs-statistik = 0.66475622525734, p-Wert = 0.5085355480285374
#   Mann-U-statistik = 652.5, p-Wert = 0.7488527394474435
#
#
# Version1 - VersionComponent zu Version0
# SetParam
#   welchs-statistik = 0.9508623556273134, p-Wert = 0.34470648632455425
#   Mann-U-statistik = 876.0, p-Wert = 0.2819761231304395
#
# SetParam_OnInit
#   welchs-statistik = 1.292115447485102, p-Wert = 0.20036063439989285
#   Mann-U-statistik = 822.0, p-Wert = 0.23796272931669005
#
# GenerateOrders
#   welchs-statistik = 1.1559889774624177, p-Wert = 0.25303803881563636
#   Mann-U-statistik = 589.5, p-Wert = 0.8873016550428182
#
# PopulateChartOrderState
#   welchs-statistik = 1.7974455992870275, p-Wert = 0.07703035799590022
#   Mann-U-statistik = 800.0, p-Wert = 0.13819027367936834
#
# OnInit_OnParam
#   welchs-statistik = 1.3540264321142264, p-Wert = 0.18182130569017324
#   Mann-U-statistik = 616.0, p-Wert = 0.7954250437430658
#
# OnParam_OnAfterRender
#   welchs-statistik = 1.457587044411478, p-Wert = 0.15026290425305283
#   Mann-U-statistik = 691.0, p-Wert = 0.909108812694557
#
# VisualizeOrderStatusSuccess
#   welchs-statistik = -0.4209693455269831, p-Wert = 0.6750780053982122
#   Mann-U-statistik = 696.5, p-Wert = 0.6694334070067189
#
# FINISH
#   welchs-statistik = 0.9871854297604666, p-Wert = 0.3275160334868249
#   Mann-U-statistik = 639.0, p-Wert = 0.7945664908416724
#
#
# Version2 - BenchmarkComponent zu Version1
#
# Version2 - VersionComponent zu Version1
# SetParam
#   welchs-statistik = 0.49715587845602416, p-Wert = 0.6205038649135967
#   Mann-U-statistik = 855.0, p-Wert = 0.6980279223645692
#
# SetParam_OnInit
#   welchs-statistik = -0.483665981136368, p-Wert = 0.6300137308056898
#   Mann-U-statistik = 725.5, p-Wert = 0.7125303266947018
#
# GenerateOrders
#   welchs-statistik = 0.6423009593055526, p-Wert = 0.522746410248002
#   Mann-U-statistik = 718.5, p-Wert = 0.5182983424195888
#
# PopulateChartOrderState
#   welchs-statistik = -0.7009482472558455, p-Wert = 0.48559683633958173
#   Mann-U-statistik = 640.0, p-Wert = 0.4903053767741645
#
# OnInit_OnParam
#   welchs-statistik = 0.8131391333685625, p-Wert = 0.4188568796010286
#   Mann-U-statistik = 741.0, p-Wert = 0.3703730629404952
#
#
# Version3 - BenchmarkComponent zu Version2
#
# Version3 - VersionComponent zu Version2
# SetParam
#   welchs-statistik = -1.604789392741108, p-Wert = 0.11262825873612763
#   Mann-U-statistik = 678.0, p-Wert = 0.12748850029505576
#
# SetParam_OnInit
#   welchs-statistik = -0.9060448803623423, p-Wert = 0.3678023204230807
#   Mann-U-statistik = 700.0, p-Wert = 0.3904882679244036
#
# PopulateChartOrderState
#   welchs-statistik = 0.6455425270138322, p-Wert = 0.5206567030656652
#   Mann-U-statistik = 701.5, p-Wert = 0.526012681565895
#
#
# Version4 - VersionComponent zu Version3
# SetParam
#   welchs-statistik = -0.6380774695464918, p-Wert = 0.5253447492096593
#   Mann-U-statistik = 703.5, p-Wert = 0.5086910218623405
#
# SetParam_OnInit
#   welchs-statistik = -0.7472147568376627, p-Wert = 0.4574516226289671
#   Mann-U-statistik = 633.0, p-Wert = 0.389928301518089
#
# GenerateOrders
#   welchs-statistik = -0.6508596633570237, p-Wert = 0.517248121806541
#   Mann-U-statistik = 643.5, p-Wert = 0.6602298612437623
#
# PopulateChartOrderState
#   welchs-statistik = -1.4720427851052795, p-Wert = 0.14556777666634335
#   Mann-U-statistik = 554.0, p-Wert = 0.15181181233934488
#
# OnInit_OnParam
#   welchs-statistik = -0.6266339897165543, p-Wert = 0.5328887805006599
#   Mann-U-statistik = 633.0, p-Wert = 0.5802888560162516
#
# OnParam_OnAfterRender
#   welchs-statistik = -0.25248668970823007, p-Wert = 0.8013877654003262
#   Mann-U-statistik = 667.0, p-Wert = 0.8537842922121888
#
# VisualizeOrderStatusSuccess
#   welchs-statistik = -0.7759961223593823, p-Wert = 0.44022865329178607
#   Mann-U-statistik = 670.0, p-Wert = 0.44019129813324354
#
# FINISH
#   welchs-statistik = -0.3023895783227437, p-Wert = 0.7632321329214972
#   Mann-U-statistik = 661.5, p-Wert = 0.8073408360788553
#
#
# Version5 - VersionComponent zu Version4
# SetParam
#   welchs-statistik = -0.7750051321160345, p-Wert = 0.44109032935531867
#   Mann-U-statistik = 610.0, p-Wert = 0.49338053317183794
#
# SetParam_OnInit
#   welchs-statistik = 1.2447934116299098, p-Wert = 0.21789958247737765
#   Mann-U-statistik = 633.0, p-Wert = 0.2223058047015184
#
# GenerateOrders
#   welchs-statistik = -0.5818653244272931, p-Wert = 0.5626652097448362
#   Mann-U-statistik = 518.5, p-Wert = 0.5004326274830477
#
# PopulateChartOrderState
#   welchs-statistik = 0.8152528185480012, p-Wert = 0.41769286783791204
#   Mann-U-statistik = 700.0, p-Wert = 0.4210841923396107
#
# OnInit_OnParam
#   welchs-statistik = -0.8581686817781611, p-Wert = 0.394055061329859
#   Mann-U-statistik = 543.0, p-Wert = 0.5579640257994792
#
# OnParam_OnAfterRender
#   welchs-statistik = -0.9957933692736977, p-Wert = 0.3231201519850654
#   Mann-U-statistik = 527.5, p-Wert = 0.4389079942864079

# %% [markdown]
# # DATA EXPLORATION

# %%
dfTilt = dfAll.pivot_table(
    values="ElapsedMilliseconds",
    index=["MethodName", "ObjInstance"],
    columns="Version",
    aggfunc=np.median
).sort_index(level=0)

plt.figure(figsize=(12, 8))
sns.heatmap(dfTilt, annot=True, fmt=".0f")

plt.title("Auflistung Methodenmittelwert")
plt.xlabel("Versionen")
plt.ylabel("Methoden und Komponenten")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\3404266072.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   dfTilt = dfAll.pivot_table(
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\3404266072.py:1: FutureWarning: The provided callable <function median at 0x000002154697A840> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   dfTilt = dfAll.pivot_table(

# %%
#chatgpt
df_pivot = dfAll.pivot_table(
    values="ElapsedMilliseconds",
    index=["MethodName", "ObjInstance"],
    columns="Version",
    aggfunc=np.median
).sort_index(level=0)

df_diff = df_pivot.diff(axis=1).iloc[:, 1:]

plt.figure(figsize=(12, 8))
sns.heatmap(df_diff, annot=True, fmt=".0f", linewidths=0.5)

plt.title("Differenz Mittelwert zur vorherigen Version")
plt.xlabel("Versionen")
plt.ylabel("Methoden und Komponenten")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\727022696.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_pivot = dfAll.pivot_table(
# C:\Users\cr\AppData\Local\Temp\ipykernel_20560\727022696.py:2: FutureWarning: The provided callable <function median at 0x000002154697A840> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_pivot = dfAll.pivot_table(

# %%
fin = dfTilt.loc["FINISH"]
fin["%"] = ((fin["Version0"] - fin["Version5"]) / fin["Version0"]) * 100
print(fin[["Version0", "Version5", "%"]])
# Out:
# Version             Version0  Version5         %
# ObjInstance
# BenchmarkComponent     480.0       NaN       NaN
# VersionComponent       474.0     457.0  3.586498
